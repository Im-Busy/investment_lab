# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [9]</a>'.</span>

# %% [markdown]
# # Regime-Aware Backtest Analysis
#
# ## Objectives
# 1. Detect market regimes (Trending/Ranging/Volatile/Transition) on SPY daily data
# 2. Run multi-pattern backtest and attribute trades to regimes
# 3. Compare strategy performance by regime type
# 4. Build regime-filtered strategy allocation recommendations
# 5. Quantify regime misclassification impact and adaptive routing benefits
#
# **Phase:** 4 — Regime Detection & Adaptive Strategy Selection
# **Status:** Notebook created per `plans/phased_implementation_plan.md` line 177

# %% [markdown]
# ## Configuration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %matplotlib inline

CONFIG = {
    "data": {"ticker": "SPY", "start": "2015-01-01", "end": "2024-12-31"},
    "regime": {"adx_threshold": 25, "atr_window": 14, "atr_percentile": 80},
    "backtest": {"cash": 100_000, "commission": 0.001},
}

# %% [markdown]
# ## 1. Load Data & Detect Regimes

# %%
df = yf.download(CONFIG["data"]["ticker"], start=CONFIG["data"]["start"], end=CONFIG["data"]["end"], auto_adjust=True, progress=False)
if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)
df.columns = [c.capitalize() if c.lower() in ["open", "high", "low", "close", "volume"] else c for c in df.columns]
df.index.name = "Date"
df.index = pd.to_datetime(df.index)
if "Volume" not in df.columns:
    df["Volume"] = 0
print(f"Loaded {len(df)} bars from {df.index[0].date()} to {df.index[-1].date()}")
df.head()
# Out:
# Loaded 2515 bars from 2015-01-02 to 2024-12-30
#                  Close        High         Low        Open     Volume
# Date
# 2015-01-02  170.124954  171.325768  169.089778  170.911698  121465900
# 2015-01-05  167.052597  169.247166  166.746189  169.081540  169632600
# 2015-01-06  165.479172  167.880776  164.684151  167.359043  209151400
# 2015-01-07  167.541214  167.880755  166.356978  166.804169  125346700
# 2015-01-08  170.514236  170.729561  168.932497  168.949050  147217800

# %%
from src.indicators.regime_detector import RegimeDetector, RegimeState
from src.strategies.adaptive_router import AdaptiveRouter

detector = RegimeDetector()
regime_info = detector.get_regime_series(df)

regime_labels = regime_info["regime"].apply(lambda r: r.value if hasattr(r, "value") else str(r))
print(f"\nRegime distribution:")
print(regime_labels.value_counts().sort_index())
print(f"\nRegime pct: {regime_labels.value_counts(normalize=True).sort_index().to_dict()}")
# Out:
# C:\Dev\projects\investment_trying\.venv\Lib\site-packages\backtesting\_plotting.py:55: UserWarning: Jupyter Notebook detected. Setting Bokeh output to notebook. This may not work in Jupyter clients without JavaScript support, such as old IDEs. Reset with `backtesting.set_bokeh_output(notebook=False)`.
#   warnings.warn('Jupyter Notebook detected. '
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f45a140d-76eb-4f9e-98a5-0df79a46b8dc">Loading BokehJS ...</span>
#     </div>
# Regime distribution:
# regime
# Ranging        938
# Transition     100
# Trending      1177
# Volatile       300
# Name: count, dtype: int64
#
# Regime pct: {'Ranging': 0.37296222664015904, 'Transition': 0.039761431411530816, 'Trending': 0.4679920477137177, 'Volatile': 0.11928429423459244}

# %% [markdown]
# ### Regime Time Series Visualization

# %%
fig, axes = plt.subplots(3, 1, figsize=(14, 10), sharex=True)
colors = {"Trending": "green", "Ranging": "orange", "Volatile": "red", "Transition": "gray"}
rcolors = regime_labels.map(colors)

axes[0].scatter(df.index, df["Close"], c=rcolors, s=2, alpha=0.7)
axes[0].set_title("SPY Close Price with Regime Labels")
axes[0].set_ylabel("Price ($)")
axes[0].legend(["Trending", "Ranging", "Volatile", "Transition"], loc="upper left", fontsize=7)

axes[1].plot(df.index, regime_info["adx"], color="purple", linewidth=0.8)
axes[1].axhline(y=25, color="green", linestyle="--", alpha=0.5, label="Trending threshold")
axes[1].axhline(y=20, color="orange", linestyle="--", alpha=0.5, label="Ranging threshold")
axes[1].set_ylabel("ADX(14)")
axes[1].legend(fontsize=7)

axes[2].plot(df.index, regime_info["atr"], color="blue", linewidth=0.8)
axes[2].axhline(y=regime_info["atr"].quantile(0.8), color="red", linestyle="--", alpha=0.5, label="80th %ile")
axes[2].set_ylabel("ATR(14)")
axes[2].set_xlabel("Date")
axes[2].legend(fontsize=7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Run Multi-Pattern Strategy (backtesting.py)

# %%
from src.strategies.backtest_py.runner import BacktestPyRunner
from src.strategies.backtest_py.multi_pattern_strategy import MultiPatternStrategy

runner = BacktestPyRunner(data=df, cash=CONFIG["backtest"]["cash"], commission=CONFIG["backtest"]["commission"])
results = runner.run(strategy_class=MultiPatternStrategy)

stats = results["stats"]
trades_df = results["trades"]
print(f"Total trades: {len(trades_df)}")
if "Return [%]" in stats:
    print(f"Return: {stats['Return [%]']:.2f}%")
    print(f"Sharpe: {stats.get('Sharpe Ratio', 'N/A')}")
    print(f"Max DD: {stats.get('Max. Drawdown [%]', 'N/A')}")
    print(f"Win Rate: {stats.get('Win Rate [%]', 'N/A')}%")
# Out:
# Running backtest on 2515 bars...
# Backtest.run:   0%|          | 0/2514 [00:00<?, ?bar/s]
# ============================================================
# BACKTEST SUMMARY
# ============================================================
# Start Date: 2015-01-02 00:00:00
# End Date: 2024-12-30 00:00:00
# Duration: 3650 days 00:00:00
#
# Initial Capital: $100,000.00
# Final Equity: $85,400.57
# Final Return: -14.60%
#
# Total Trades: 47
# Win Rate: 21.28%
# Best Trade: 12.80%
# Worst Trade: -11.55%
# Avg Trade: -1.92%
#
# Max Drawdown: -16.50%
# Sharpe Ratio: -0.62
# Sortino Ratio: -0.80
# Calmar Ratio: -0.10
# ============================================================
#
# Total trades: 47
# Return: -14.60%
# Sharpe: -0.6156281940676381
# Max DD: -16.499948726994074
# Win Rate: 21.27659574468085%

# %% [markdown]
# ## 3. Attribute Trades to Regimes

# %%
if not trades_df.empty and len(trades_df) > 0:
    entry_times = pd.to_datetime(trades_df["entry_time"])
    regime_info["regime_str"] = regime_info["regime"].apply(lambda r: r.value if hasattr(r, "value") else str(r))
    
    entry_regimes = []
    for et in entry_times:
        prior = regime_info.loc[regime_info.index <= et]
        if not prior.empty:
            entry_regimes.append(prior.iloc[-1]["regime_str"])
        else:
            entry_regimes.append("Unknown")
    
    trades_df_copy = trades_df.copy()
    trades_df_copy["regime_at_entry"] = entry_regimes
    
    print(f"Trade regime attribution:")
    regime_trade_counts = trades_df_copy["regime_at_entry"].value_counts()
    print(regime_trade_counts.to_string())
else:
    trades_df_copy = pd.DataFrame()
    print("No trades to attribute.")
# Out:
# Trade regime attribution:
# regime_at_entry
# Ranging       25
# Trending      18
# Volatile       3
# Transition     1

# %% [markdown]
# ### Performance by Regime

# %%
if not trades_df_copy.empty and len(trades_df_copy) > 0:
    pnl_col = "return_pct" if "return_pct" in trades_df_copy.columns else "ReturnPct" if "ReturnPct" in trades_df_copy.columns else None
    if pnl_col:
        regime_perf = trades_df_copy.groupby("regime_at_entry").agg(
            trade_count=(pnl_col, "count"),
            mean_return=(pnl_col, "mean"),
            median_return=(pnl_col, "median"),
            std_return=(pnl_col, "std"),
            win_rate=(pnl_col, lambda x: (x > 0).mean()),
            cum_return=(pnl_col, "sum"),
        ).round(2)
        
        print("\n=== PERFORMANCE BY REGIME ===")
        print(regime_perf.to_string())
        
        fig, axes = plt.subplots(1, 2, figsize=(14, 5))
        
        axes[0].bar(regime_perf.index, regime_perf["mean_return"], color=[colors.get(r, "gray") for r in regime_perf.index])
        axes[0].set_title("Mean Return by Regime")
        axes[0].set_ylabel("Return (%)")
        axes[0].axhline(y=0, color="black", linewidth=0.5)
        
        axes[1].bar(regime_perf.index, regime_perf["win_rate"], color=[colors.get(r, "gray") for r in regime_perf.index])
        axes[1].set_title("Win Rate by Regime")
        axes[1].set_ylabel("Win Rate")
        
        plt.tight_layout()
        plt.show()
# Out:
# === PERFORMANCE BY REGIME ===
#                  trade_count  mean_return  median_return  std_return  win_rate  cum_return
# regime_at_entry
# Ranging                   25        -0.02          -0.01        0.03      0.16       -0.43
# Transition                 1        -0.01          -0.01         NaN      0.00       -0.01
# Trending                  18        -0.02          -0.02        0.05      0.28       -0.30
# Volatile                   3        -0.04          -0.07        0.06      0.33       -0.12

# %% [markdown]
# ## 4. Regime-Filtered Strategy Simulation

# %%
from src.strategies.adaptive_router import AdaptiveRouter

router = AdaptiveRouter()

if not trades_df_copy.empty and len(trades_df_copy) > 0 and pnl_col:
    simulated_static_return = trades_df_copy[pnl_col].sum()
    
    filtered_rows = []
    for idx, row in trades_df_copy.iterrows():
        regime_str = row["regime_at_entry"]
        regime_state = RegimeState[regime_str.upper()] if regime_str in [r.name for r in RegimeState] else RegimeState.TRANSITION
        
        et = pd.Timestamp(row["entry_time"])
        active = router.get_active_strategies(["MultiPattern"], regime_state)
        
        if "MultiPattern" in active:
            filtered_rows.append(row)
    
    if filtered_rows:
        filtered_df = pd.DataFrame(filtered_rows)
        simulated_filtered_return = filtered_df[pnl_col].sum()
        
        print(f"\n=== STRATEGY SIMULATION ===")
        print(f"Static (no filter): {simulated_static_return:.2f}% cumulative, {len(trades_df_copy)} trades")
        print(f"Regime-filtered:    {simulated_filtered_return:.2f}% cumulative, {len(filtered_df)} trades")
        print(f"Difference:         {simulated_filtered_return - simulated_static_return:+.2f}%")
    else:
        print("No regime-filtered trades found.")
# Out:
# === STRATEGY SIMULATION ===
# Static (no filter): -0.86% cumulative, 47 trades
# Regime-filtered:    -0.86% cumulative, 47 trades
# Difference:         +0.00%

# %% [markdown]
# ## 5. Active Strategy Count by Regime Over Time

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
regime_ts = router.get_regime_time_series(df)
regime_ts["active_strategy_pct"] = regime_ts["active_strategy_count"] / len(router.strategy_regime_map) * 100

print(f"\nActive strategies by regime:")
regime_summary = regime_ts.groupby("regime").agg(
    avg_active=("active_strategy_count", "mean"),
    min_active=("active_strategy_count", "min"),
    max_active=("active_strategy_count", "max"),
    bar_count=("regime", "count"),
).round(1)
print(regime_summary.to_string())

fig, ax = plt.subplots(figsize=(14, 5))
ax.bar(regime_summary.index, regime_summary["avg_active"], color=[colors.get(r, "gray") for r in regime_summary.index])
ax.set_title("Average Active Strategies by Regime")
ax.set_ylabel("Number of Active Strategies")
ax.set_xlabel("Regime")
plt.tight_layout()
plt.show()
# Out:
# Active strategies by regime:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\algorithms.py:1497, in safe_sort(values, codes, use_na_sentinel, assume_unique, verify)
#    1496 try:
# -> 1497     sorter = values.argsort()
#    1498     ordered = values.take(sorter)
#
# TypeError: '<' not supported between instances of 'RegimeState' and 'RegimeState'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)     64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#
# TypeError: '<' not supported between instances of 'RegimeState' and 'RegimeState'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       2 regime_ts["active_strategy_pct"] = regime_ts["active_strategy_count"] / len(router.strategy_regime_map) * 100
#       4 print(f"\nActive strategies by regime:")
# ----> 5 regime_summary = regime_ts.groupby("regime").agg(
#       6     avg_active=("active_strategy_count", "mean"),
#       7     min_active=("active_strategy_count", "min"),
#       8     max_active=("active_strategy_count", "max"),
#       9     bar_count=("regime", "count"),
#      10 ).round(1)
#      11 print(regime_summary.to_string())
#      13 fig, ax = plt.subplots(figsize=(14, 5))
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\groupby\generic.py:2291, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    2288     kwargs["engine_kwargs"] = engine_kwargs
#    2290 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 2291 result = op.agg()
#    2292 if not is_dict_like(func) and result is not None:
#    2293     # GH #52849
#    2294     if not self.as_index and is_list_like(func):
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\apply.py:294, in Apply.agg(self)
#     291     return self.apply_str()
#     293 if is_dict_like(func):
# --> 294     return self.agg_dict_like()
#     295 elif is_list_like(func):
#     296     # we require a list, but not a 'str'
#     297     return self.agg_list_like()
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\apply.py:511, in Apply.agg_dict_like(self)
#     503 def agg_dict_like(self) -> DataFrame | Series:
#     504     """
#     505     Compute aggregation in the case of a dict-like argument.
#     506
#    (...)    509     Result of aggregation.
#     510     """
# --> 511     return self.agg_or_apply_dict_like(op_name="agg")
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\apply.py:1677, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1672     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1674 with com.temp_setattr(
#    1675     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1676 ):
# -> 1677     result_index, result_data = self.compute_dict_like(
#    1678         op_name, selected_obj, selection, kwargs
#    1679     )
#    1680 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1681 return result
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\apply.py:592, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     590 if cols.ndim == 1:
#     591     series = obj._gotitem(key, ndim=1, subset=cols)
# --> 592     results.append(getattr(series, op_name)(how, **kwargs))
#     593     keys.append(key)
#     594 else:
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\groupby\generic.py:464, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     462 kwargs["engine"] = engine
#     463 kwargs["engine_kwargs"] = engine_kwargs
# --> 464 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     465 if relabeling:
#     466     # columns is not narrowed by mypy from relabeling flag
#     467     assert columns is not None  # for mypy
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\groupby\generic.py:522, in SeriesGroupBy._aggregate_multiple_funcs(self, arg, *args, **kwargs)
#     520     for idx, (name, func) in enumerate(arg):
#     521         key = base.OutputKey(label=name, position=idx)
# --> 522         results[key] = self.aggregate(func, *args, **kwargs)
#     524 if any(isinstance(x, DataFrame) for x in results.values()):
#     525     from pandas import concat
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\groupby\generic.py:456, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     454     if engine_kwargs is not None:
#     455         kwargs["engine_kwargs"] = engine_kwargs
# --> 456     return getattr(self, func)(*args, **kwargs)
#     458 elif isinstance(func, abc.Iterable):
#     459     # Catch instances of lists / tuples
#     460     # but not the class list / tuple itself.
#     461     func = maybe_mangle_lambdas(func)
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\internals\managers.py:2274, in SingleBlockManager.grouped_reduce(self, func)
#    2272 def grouped_reduce(self, func):
#    2273     arr = self.array
# -> 2274     res = func(arr)
#    2275     index = default_index(len(res))
#    2277     mgr = type(self).from_array(res, index)
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\groupby\ops.py:961, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     956 """
#     957 Returns the values of a cython operation.
#     958 """
#     959 assert kind in ["transform", "aggregate"]
# --> 961 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
#     963 return cy_op.cython_operation(
#     964     values=values,
#     965     axis=axis,
#    (...)    969     **kwargs,
#     970 )
#
# File pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\groupby\ops.py:756, in BaseGrouper.has_dropped_na(self)
#     750 @final
#     751 @cache_readonly
#     752 def has_dropped_na(self) -> bool:
#     753     """
#     754     Whether grouper has null value(s) that are dropped.
#     755     """
# --> 756     return bool((self.ids < 0).any())
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\groupby\ops.py:774, in BaseGrouper.ids(self)
#     772 @property
#     773 def ids(self) -> npt.NDArray[np.intp]:
# --> 774     return self.result_index_and_ids[1]
#
# File pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\groupby\ops.py:779, in BaseGrouper.result_index_and_ids(self)
#     776 @cache_readonly
#     777 def result_index_and_ids(self) -> tuple[Index, npt.NDArray[np.intp]]:
#     778     levels = [
# --> 779         Index._with_infer(ping.uniques, copy=False) for ping in self.groupings
#     780     ]
#     781     obs = [
#     782         ping._observed or not ping._passed_categorical for ping in self.groupings
#     783     ]
#     784     sorts = [ping._sort for ping in self.groupings]
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\groupby\grouper.py:618, in Grouping.uniques(self)
#     616 @property
#     617 def uniques(self) -> ArrayLike:
# --> 618     return self._codes_and_uniques[1]
#
# File pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\groupby\grouper.py:680, in Grouping._codes_and_uniques(self)
#     675     uniques = self._uniques
#     676 else:
#     677     # GH35667, replace dropna=False with use_na_sentinel=False
#     678     # error: Incompatible types in assignment (expression has type "Union[
#     679     # ndarray[Any, Any], Index]", variable has type "Categorical")
# --> 680     codes, uniques = algorithms.factorize(  # type: ignore[assignment]
#     681         self.grouping_vector, sort=self._sort, use_na_sentinel=self._dropna
#     682     )
#     683 return codes, uniques
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\algorithms.py:828, in factorize(values, sort, use_na_sentinel, size_hint)
#     821     codes, uniques = factorize_array(
#     822         values,
#     823         use_na_sentinel=use_na_sentinel,
#     824         size_hint=size_hint,
#     825     )
#     827 if sort and len(uniques) > 0:
# --> 828     uniques, codes = safe_sort(
#     829         uniques,
#     830         codes,
#     831         use_na_sentinel=use_na_sentinel,
#     832         assume_unique=True,
#     833         verify=False,
#     834     )
#     836 uniques = _reconstruct_data(uniques, original.dtype, original)
#     838 return codes, uniques
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\algorithms.py:1509, in safe_sort(values, codes, use_na_sentinel, assume_unique, verify)
#    1507             ordered = _sort_tuples(values)  # type: ignore[arg-type]
#    1508         else:
# -> 1509             ordered = _sort_mixed(values)
#    1511 # codes:
#    1513 if codes is None:
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\pandas\core\algorithms.py:1561, in _sort_mixed(values)
#    1559 num_pos = ~str_pos & ~null_pos
#    1560 str_argsort = np.argsort(values[str_pos])
# -> 1561 num_argsort = np.argsort(values[num_pos])
#    1562 # convert boolean arrays to positional indices, then order by underlying values
#    1563 str_locs = str_pos.nonzero()[0].take(str_argsort)
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:1243, in argsort(a, axis, kind, order, stable)
#    1130 @array_function_dispatch(_argsort_dispatcher)
#    1131 def argsort(a, axis=-1, kind=None, order=None, *, stable=None):
#    1132     """
#    1133     Returns the indices that would sort an array.
#    1134
#    (...)   1241
#    1242     """
# -> 1243     return _wrapfunc(
#    1244         a, 'argsort', axis=axis, kind=kind, order=order, stable=stable
#    1245     )
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:66, in _wrapfunc(obj, method, *args, **kwds)
#      57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)     64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
# ---> 66     return _wrapit(obj, method, *args, **kwds)
#
# File C:\Dev\projects\investment_trying\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:46, in _wrapit(obj, method, *args, **kwds)
#      43 # As this already tried the method, subok is maybe quite reasonable here
#      44 # but this follows what was done before. TODO: revisit this.
#      45 arr, = conv.as_arrays(subok=False)
# ---> 46 result = getattr(arr, method)(*args, **kwds)
#      48 return conv.wrap(result, to_scalar=False)
#
# TypeError: '<' not supported between instances of 'RegimeState' and 'RegimeState'

# %% [markdown]
# ## 6. Equity Curve Split by Regime

# %%
if not trades_df_copy.empty and len(trades_df_copy) > 0 and pnl_col:
    equity_curve = pd.Series(0.0, index=df.index)
    
    for regime_name in ["Trending", "Ranging", "Volatile", "Transition"]:
        mask = trades_df_copy["regime_at_entry"] == regime_name
        regime_trades = trades_df_copy[mask].copy()
        if regime_trades.empty:
            continue
        
        cumret = (1 + regime_trades[pnl_col] / 100).cumprod() - 1
        plt.plot(regime_trades["entry_time"], cumret * 100, label=f"{regime_name} ({len(regime_trades)} trades)", linewidth=1.5)
    
    plt.title("Cumulative Return by Regime at Entry")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return (%)")
    plt.legend(fontsize=8)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 7. Summary & Recommendations

# %%
print("=" * 70)
print("REGIME-AWARE BACKTEST SUMMARY")
print("=" * 70)

print(f"\n1. REGIME DISTRIBUTION")
for regime, count in regime_labels.value_counts().sort_index().items():
    pct = count / len(regime_labels) * 100
    print(f"   {regime:>12s}: {count:>5d} bars ({pct:>5.1f}%)")

if not trades_df_copy.empty and len(trades_df_copy) > 0 and pnl_col:
    print(f"\n2. TRADE PERFORMANCE BY REGIME")
    for regime_name in ["Trending", "Ranging", "Volatile", "Transition"]:
        sub = trades_df_copy[trades_df_copy["regime_at_entry"] == regime_name]
        if len(sub) == 0:
            continue
        wr = (sub[pnl_col] > 0).mean()
        mr = sub[pnl_col].mean()
        print(f"   {regime_name:>12s}: {len(sub):>3d} trades, WR={wr:.0%}, Mean={mr:+.2f}%")

regime_rec = router.get_regime_recommendations(RegimeState.TRENDING)
print(f"\n3. ROUTER RECOMMENDATIONS")
print(f"   Enabled: {', '.join(regime_rec['enabled'])}")
print(f"   Disabled: {', '.join(regime_rec['disabled'])}")
print(f"   Advice: {regime_rec['advice']}")

print("\n" + "=" * 70)
print("CONCLUSION")
print("=" * 70)
if not trades_df_copy.empty and len(trades_df_copy) > 0 and pnl_col:
    best_regime = trades_df_copy.groupby("regime_at_entry")[pnl_col].mean().idxmax()
    worst_regime = trades_df_copy.groupby("regime_at_entry")[pnl_col].mean().idxmin()
    print(f"Best performing regime: {best_regime}")
    print(f"Worst performing regime: {worst_regime}")
    print(f"\nRegime-based filtering is most valuable when the strategy has")
    print(f"significantly different performance across regimes.")
    print(f"Consider adjusting confluence thresholds or position sizing")
    print(f"based on detected regime to improve risk-adjusted returns.")
